# %%
import pandas as pd
from nsepy import get_history
from datetime import date
import datetime as dt

# %%
company_name_adaniports = 'ADANIPORTS'
company_name_asianpaint = 'ASIANPAINT'
company_name_axisbank = 'AXISBANK'
company_name_bajaj_auto = 'BAJAJ-AUTO'
company_name_bajajfinsv = 'BAJAJFINSV'

company_name_bajfinance = 'BAJFINANCE'
company_name_bhartiartl = 'BHARTIARTL'
company_name_bpcl = 'BPCL'
company_name_britannia = 'BRITANNIA'
company_name_cipla = 'CIPLA'

company_name_coalindia = 'COALINDIA'
company_name_divislab = 'DIVISLAB'
company_name_drreddy = 'DRREDDY'
company_name_eichermot = 'EICHERMOT'
company_name_grasim = 'GRASIM'

company_name_hcltech = 'HCLTECH'
company_name_hdfc = 'HDFC'
company_name_hdfcbank = 'HDFCBANK'
company_name_hdfclife = 'HDFCLIFE'
company_name_heromotoco = 'HEROMOTOCO'

company_name_hindalco = 'HINDALCO'
company_name_hindunilvr = 'HINDUNILVR'
company_name_icicibank = 'ICICIBANK'
company_name_indusindbk = 'INDUSINDBK'
company_name_infy = 'INFY'

company_name_ioc = 'IOC'
company_name_itc = 'ITC'
company_name_jswsteel = 'JSWSTEEL'
company_name_kotakbank = 'KOTAKBANK'
company_name_lt = 'LT'

company_name_m_m = 'M&M'
company_name_maruti = 'MARUTI'
company_name_nestleind = 'NESTLEIND'
company_name_ntpc = 'NTPC'
company_name_ongc = 'ONGC'

company_name_powergrid = 'POWERGRID'
company_name_reliance = 'RELIANCE'
company_name_sbilife = 'SBILIFE'
company_name_sbin = 'SBIN'
company_name_shreecem = 'SHREECEM'

company_name_sunpharma = 'SUNPHARMA'
company_name_tataconsum = 'TATACONSUM'
company_name_tatamotors = 'TATAMOTORS'
company_name_tatasteel = 'TATASTEEL'
company_name_tcs = 'TCS'

company_name_techm = 'TECHM'
company_name_titan = 'TITAN'
company_name_ultracemco = 'ULTRACEMCO'
company_name_upl = 'UPL'
company_name_wipro = 'WIPRO'

company_name_pnb = 'PNB'

# %%
start_date = date(2021,6,11)
end_date = date(2021,6,11)

# %%
data_adaniports = get_history(symbol=company_name_adaniports, start=start_date, end=end_date)
data_asianpaint = get_history(symbol=company_name_asianpaint, start=start_date, end=end_date)
data_axisbank = get_history(symbol=company_name_axisbank, start=start_date, end=end_date)
data_bajaj_auto = get_history(symbol=company_name_bajaj_auto, start=start_date, end=end_date)
data_bajajfinsv = get_history(symbol=company_name_bajajfinsv, start=start_date, end=end_date)

# %%
data_bajfinance = get_history(symbol=company_name_bajfinance, start=start_date, end=end_date)
data_bhartiartl = get_history(symbol=company_name_bhartiartl, start=start_date, end=end_date)
data_bpcl = get_history(symbol=company_name_bpcl, start=start_date, end=end_date)
data_britannia = get_history(symbol=company_name_britannia, start=start_date, end=end_date)
data_cipla = get_history(symbol=company_name_cipla, start=start_date, end=end_date)

# %%
data_coalindia = get_history(symbol=company_name_coalindia, start=start_date, end=end_date)
data_divislab = get_history(symbol=company_name_divislab, start=start_date, end=end_date)
data_drreddy = get_history(symbol=company_name_drreddy, start=start_date, end=end_date)
data_eichermot = get_history(symbol=company_name_eichermot, start=start_date, end=end_date)
data_grasim = get_history(symbol=company_name_grasim, start=start_date, end=end_date)

# %%
data_hcltech = get_history(symbol=company_name_hcltech, start=start_date, end=end_date)
data_hdfc = get_history(symbol=company_name_hdfc, start=start_date, end=end_date)
data_hdfcbank = get_history(symbol=company_name_hdfcbank, start=start_date, end=end_date)
data_hdfclife = get_history(symbol=company_name_hdfclife, start=start_date, end=end_date)
data_heromotoco = get_history(symbol=company_name_heromotoco, start=start_date, end=end_date)

# %%
data_hindalco = get_history(symbol=company_name_hindalco, start=start_date, end=end_date)
data_hindunilvr = get_history(symbol=company_name_hindunilvr, start=start_date, end=end_date)
data_icicibank = get_history(symbol=company_name_icicibank, start=start_date, end=end_date)
data_indusindbk = get_history(symbol=company_name_indusindbk, start=start_date, end=end_date)
data_infy = get_history(symbol=company_name_infy, start=start_date, end=end_date)

# %%
data_ioc = get_history(symbol=company_name_ioc, start=start_date, end=end_date)
data_itc = get_history(symbol=company_name_itc, start=start_date, end=end_date)
data_jswsteel = get_history(symbol=company_name_jswsteel, start=start_date, end=end_date)
data_kotakbank = get_history(symbol=company_name_kotakbank, start=start_date, end=end_date)
data_lt = get_history(symbol=company_name_lt, start=start_date, end=end_date)

# %%
data_m_m = get_history(symbol=company_name_m_m, start=start_date, end=end_date)
data_maruti = get_history(symbol=company_name_maruti, start=start_date, end=end_date)
data_nestleind = get_history(symbol=company_name_nestleind, start=start_date, end=end_date)
data_ntpc = get_history(symbol=company_name_ntpc, start=start_date, end=end_date)
data_ongc = get_history(symbol=company_name_ongc, start=start_date, end=end_date)

# %%
data_powergrid = get_history(symbol=company_name_powergrid, start=start_date, end=end_date)
data_reliance = get_history(symbol=company_name_reliance, start=start_date, end=end_date)
data_sbilife = get_history(symbol=company_name_sbilife, start=start_date, end=end_date)
data_sbin = get_history(symbol=company_name_sbin, start=start_date, end=end_date)
data_shreecem = get_history(symbol=company_name_shreecem, start=start_date, end=end_date)

# %%
data_sunpharma = get_history(symbol=company_name_sunpharma, start=start_date, end=end_date)
data_tataconsum = get_history(symbol=company_name_tataconsum, start=start_date, end=end_date)
data_tatamotors = get_history(symbol=company_name_tatamotors, start=start_date, end=end_date)
data_tatasteel = get_history(symbol=company_name_tatasteel, start=start_date, end=end_date)
data_tcs = get_history(symbol=company_name_tcs, start=start_date, end=end_date)

# %%
data_techm = get_history(symbol=company_name_techm, start=start_date, end=end_date)
data_titan = get_history(symbol=company_name_titan, start=start_date, end=end_date)
data_ultracemco = get_history(symbol=company_name_ultracemco, start=start_date, end=end_date)
data_upl = get_history(symbol=company_name_upl, start=start_date, end=end_date)
data_wipro = get_history(symbol=company_name_wipro, start=start_date, end=end_date)

# %%
data_pnb = get_history(symbol=company_name_pnb, start=start_date, end=end_date)

# %%
frames = [data_adaniports, data_asianpaint, data_axisbank, data_bajaj_auto, data_bajajfinsv, data_bajfinance, data_bhartiartl, data_bpcl, data_britannia, data_cipla, data_coalindia, data_divislab, data_drreddy, data_eichermot, data_grasim, data_hcltech, data_hdfc, data_hdfcbank, data_hdfclife, data_heromotoco, data_hindalco, data_hindunilvr, data_icicibank, data_indusindbk, data_infy, data_ioc, data_itc, data_jswsteel, data_kotakbank, data_lt, data_m_m, data_maruti, data_nestleind, data_ntpc, data_ongc, data_powergrid, data_reliance, data_sbilife, data_sbin, data_shreecem, data_sunpharma, data_tataconsum, data_tatamotors, data_tatasteel, data_tcs, data_techm, data_titan, data_ultracemco, data_upl, data_wipro, data_pnb]
result = pd.concat(frames)

# %%
drop_col = ['Series', 'Trades', 'Turnover']

# %%
result.drop(drop_col, axis='columns', inplace=True)

# %%
result['Open Diff']=result['Open']-result['Prev Close']

# %%
result['Day Close Diff']=result['Close']-result['Open']

# %%
result['%Deliverble'] = result['%Deliverble']  * 100

# %%
result
# Out:
#                 Symbol  Prev Close      Open      High       Low      Last  \
# Date
# 2021-06-11  ADANIPORTS      846.75    852.00    856.40    820.70    841.70
# 2021-06-11  ASIANPAINT     2950.60   2960.00   2971.60   2938.60   2955.10
# 2021-06-11    AXISBANK      744.25    746.25    746.25    737.00    737.50
# 2021-06-11  BAJAJ-AUTO     4179.90   4185.00   4216.85   4162.00   4173.00
# 2021-06-11  BAJAJFINSV    11993.10  12000.00  12080.00  11852.90  11900.00
# 2021-06-11  BAJFINANCE     6086.40   6105.35   6230.00   6045.20   6115.00
# 2021-06-11  BHARTIARTL      545.15    545.50    549.75    540.05    541.50
# 2021-06-11        BPCL      483.55    485.70    489.50    481.70    483.95
# 2021-06-11   BRITANNIA     3576.30   3575.00   3595.00   3551.00   3553.30
# 2021-06-11       CIPLA      974.20    975.00    982.30    965.50    967.65
# 2021-06-11   COALINDIA      156.50    157.00    165.00    156.65    162.25
# ...
