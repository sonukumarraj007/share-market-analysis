# %%
import pandas as pd
from nsepy import get_history
from datetime import date
import datetime as dt
from datetime import datetime

# %%
company_name = 'SBIN'
start = datetime(2020, 1, 1)
end = datetime(2021, 12, 24)

# %%
start
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %%
data = get_history(symbol=company_name, start=start, end=end)

# %%
drop_col = ['Series', 'Trades', 'Turnover']

# %%
data.drop(drop_col, axis='columns', inplace=True)

# %%
data['Open Diff']=data['Open']-data['Prev Close']

# %%
data['Day Close Diff']=data['Close']-data['Open']

# %%
data['%Deliverble'] = data['%Deliverble']  * 100

# %%
data['Volume'] = ((data['Volume'] / 1000000).apply(lambda x: '{:,.1f} M'.format(x)))

# %%
data['Deliverable Volume'] = (data['Deliverable Volume'] / 1000000).round(decimals=1).astype(str) + ' M'

# %%
data.head(44)
# Out:
#            Symbol  Prev Close    Open    High     Low    Last   Close    VWAP  \
# Date
# 2020-01-01   SBIN      333.75  334.70  335.95  332.15  335.00  334.45  334.03
# 2020-01-02   SBIN      334.45  334.50  339.85  333.35  338.80  339.30  336.81
# 2020-01-03   SBIN      339.30  337.95  337.95  332.00  334.00  333.70  335.08
# 2020-01-06   SBIN      333.70  331.70  331.70  317.70  318.40  319.00  322.03
# 2020-01-07   SBIN      319.00  324.45  327.00  315.40  317.90  318.40  320.38
# 2020-01-08   SBIN      318.40  312.10  321.50  311.00  319.35  319.80  315.88
# 2020-01-09   SBIN      319.80  326.90  331.40  325.00  330.10  330.20  328.58
# 2020-01-10   SBIN      330.20  331.00  337.95  328.10  332.45  332.25  333.63
# 2020-01-13   SBIN      332.25  334.00  335.45  329.05  330.60  330.75  331.73
# 2020-01-14   SBIN      330.75  329.80  331.70  326.50  328.10  328.00  328.53
# 2020-01-15   SBIN      328.00  329.00  329.20  322.35  324.00  324.25  324.30
# ...
