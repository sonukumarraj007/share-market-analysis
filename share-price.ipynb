# %%
import pandas as pd
from nsepy import get_history
from datetime import date
import datetime as dt

# %%
company_name = 'RELIANCE'

# %%
 data = get_history(symbol=company_name, start=date(2021,5,1), end=date(2021,6,16))
# df.to_csv('temp.csv')

# %%
# data = pd.read_csv('temp.csv', parse_dates=["Date"], index_col="Date")
#data = pd.read_csv('temp.csv', parse_dates=["Date"])

# %%
drop_col = ['Symbol', 'Series', 'Trades', 'Turnover']

# %%
#data.drop(drop_col, axis='columns', inplace=True)

# %%
data['Open Diff']=data['Open']-data['Prev Close']

# %%
data['Day Close Diff']=data['Close']-data['Open']

# %%
#data['Day Of Week'] = data['Date'].dt.day_name()

# %%
data['%Deliverble'] = data['%Deliverble']  * 100

# %%
data.head()
# Out:
#               Symbol Series  Prev Close     Open     High      Low    Last  \
# Date
# 2021-05-03  RELIANCE     EQ     1994.50  1966.00  1979.00  1943.10  1956.0
# 2021-05-04  RELIANCE     EQ     1959.05  1950.00  1967.80  1911.00  1918.0
# 2021-05-05  RELIANCE     EQ     1916.60  1923.35  1938.50  1908.05  1921.5
# 2021-05-06  RELIANCE     EQ     1920.10  1921.85  1935.00  1906.60  1932.0
# 2021-05-07  RELIANCE     EQ     1931.00  1937.75  1955.65  1926.00  1926.8
#
#               Close     VWAP    Volume      Turnover  Trades  \
# Date
# 2021-05-03  1959.05  1958.46  10909942  2.136664e+15  343806
# 2021-05-04  1916.60  1935.83  10083693  1.952033e+15  325798
# 2021-05-05  1920.10  1923.26   5719649  1.100036e+15  190990
# 2021-05-06  1931.00  1920.95   6749281  1.296502e+15  221666
# 2021-05-07  1931.75  1940.01   5671163  1.100213e+15  188670
#
#             Deliverable Volume  %Deliverble  Open Diff  Day Close Diff
# Date
# ...

# %%
# data.reset_index(inplace = True)
#data.set_index('Date', inplace=True)

# %%
data.head()
# Out:
#               Symbol Series  Prev Close     Open     High      Low    Last  \
# Date
# 2021-05-03  RELIANCE     EQ     1994.50  1966.00  1979.00  1943.10  1956.0
# 2021-05-04  RELIANCE     EQ     1959.05  1950.00  1967.80  1911.00  1918.0
# 2021-05-05  RELIANCE     EQ     1916.60  1923.35  1938.50  1908.05  1921.5
# 2021-05-06  RELIANCE     EQ     1920.10  1921.85  1935.00  1906.60  1932.0
# 2021-05-07  RELIANCE     EQ     1931.00  1937.75  1955.65  1926.00  1926.8
#
#               Close     VWAP    Volume      Turnover  Trades  \
# Date
# 2021-05-03  1959.05  1958.46  10909942  2.136664e+15  343806
# 2021-05-04  1916.60  1935.83  10083693  1.952033e+15  325798
# 2021-05-05  1920.10  1923.26   5719649  1.100036e+15  190990
# 2021-05-06  1931.00  1920.95   6749281  1.296502e+15  221666
# 2021-05-07  1931.75  1940.01   5671163  1.100213e+15  188670
#
#             Deliverable Volume  %Deliverble  Open Diff  Day Close Diff
# Date
# ...

# %%
data.tail(45)
# Out:
#               Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2021-05-03  RELIANCE     EQ     1994.50  1966.00  1979.00  1943.10  1956.00
# 2021-05-04  RELIANCE     EQ     1959.05  1950.00  1967.80  1911.00  1918.00
# 2021-05-05  RELIANCE     EQ     1916.60  1923.35  1938.50  1908.05  1921.50
# 2021-05-06  RELIANCE     EQ     1920.10  1921.85  1935.00  1906.60  1932.00
# 2021-05-07  RELIANCE     EQ     1931.00  1937.75  1955.65  1926.00  1926.80
# 2021-05-10  RELIANCE     EQ     1931.75  1939.00  1946.80  1920.95  1927.10
# 2021-05-11  RELIANCE     EQ     1926.20  1915.00  1938.55  1910.00  1933.90
# 2021-05-12  RELIANCE     EQ     1933.15  1930.10  1932.90  1907.00  1913.05
# 2021-05-14  RELIANCE     EQ     1913.15  1928.05  1942.00  1906.00  1937.00
# 2021-05-17  RELIANCE     EQ     1937.30  1937.30  1963.45  1930.40  1958.85
# 2021-05-18  RELIANCE     EQ     1960.35  1981.00  2002.60  1972.50  1986.00
# ...

# %%
# data.dtypes
# data.shape
# data.index

# %%
data = data[['Day Of Week','Prev Close','Open', 'High', 'Low', 'Last', 'Close','Open Diff', 'Day Close Diff']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-fd8535ede7bf> in <module>
# ----> 1 data = data[['Day Of Week','Prev Close','Open', 'High', 'Low', 'Last', 'Close','Open Diff', 'Day Close Diff']]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
# ...

# %%
data.head()
# Out:
#            Day Of Week  Prev Close   Open   High    Low   Last  Close  \
# Date
# 2002-04-26      Friday        31.0  40.00  40.00  35.00  37.30  37.40
# 2002-04-29      Monday        37.4  38.50  39.10  37.65  39.10  38.60
# 2002-04-30     Tuesday        38.6  39.00  40.35  38.50  40.15  40.10
# 2002-05-02    Thursday        40.1  40.25  46.10  40.25  45.10  44.80
# 2002-05-03      Friday        44.8  45.80  47.45  44.55  46.95  46.45
#
#             Open Diff  Day Close Diff
# Date
# 2002-04-26       9.00           -2.60
# 2002-04-29       1.10            0.10
# 2002-04-30       0.40            1.10
# 2002-05-02       0.15            4.55
# 2002-05-03       1.00            0.65

# %%
# df['Close'].mean()
data_2010 = data.loc['2010']
data_2011 = data.loc['2011']
data_2012 = data.loc['2012']
data_2013 = data.loc['2013']
data_2014 = data.loc['2014']
data_2015 = data.loc['2015']
data_2016 = data.loc['2016']
data_2017 = data.loc['2017']
data_2018 = data.loc['2018']
data_2019 = data.loc['2019']
data_2020 = data.loc['2020']
data_2021 = data.loc['2021']

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(company_name+'.xlsx', engine='xlsxwriter')

# %%
# Write each dataframe to a different worksheet.
data_2010.to_excel(writer, sheet_name='2010')
data_2011.to_excel(writer, sheet_name='2011')
data_2012.to_excel(writer, sheet_name='2012')
data_2013.to_excel(writer, sheet_name='2013')
data_2014.to_excel(writer, sheet_name='2014')
data_2015.to_excel(writer, sheet_name='2015')
data_2016.to_excel(writer, sheet_name='2016')
data_2017.to_excel(writer, sheet_name='2017')
data_2018.to_excel(writer, sheet_name='2018')
data_2019.to_excel(writer, sheet_name='2019')
data_2020.to_excel(writer, sheet_name='2020')
data_2021.to_excel(writer, sheet_name='2021')

# %%
# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
nifty = get_history(symbol="NIFTY", start=date(2015,1,1), end=date(2015,1,10),index=True)

# %%
nifty
# Out:
#                Open     High      Low    Close     Volume      Turnover
# Date
# 2015-01-01  8272.80  8294.70  8248.75  8284.00   56560411  2.321880e+10
# 2015-01-02  8288.70  8410.60  8288.70  8395.45  101887024  4.715720e+10
# 2015-01-05  8407.95  8445.60  8363.90  8378.40  118160545  5.525520e+10
# 2015-01-06  8325.30  8327.85  8111.35  8127.35  172799618  8.089190e+10
# 2015-01-07  8118.65  8151.20  8065.45  8102.10  164075424  7.464330e+10
# 2015-01-08  8191.40  8243.50  8167.30  8234.60  143802802  8.147400e+10
# 2015-01-09  8285.45  8303.30  8190.80  8284.50  152612528  9.305950e+10
